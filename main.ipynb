# %%
import comet_ml
comet_ml.login()

from ultralytics import YOLO
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = YOLO("yolo26n.pt")  # REQUIRED

# %%
results = model.train(
    data="./data/data.yaml",
    epochs=100,
    batch=32,
    imgsz=416,
    project="VehicleCountingModel",
    name="yolo11s_vehicles",
)
# Out:
# Ultralytics 8.4.14  Python-3.13.5 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...
